# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
folder1 = '022-intact-vs-split-ecfs-rep1'
folder2 = '023-intact-vs-split-ecfs-rep2'

# %%
df1 = pd.read_csv('datasets/experiment/{}/fluos-lower-2.csv'.format(folder1))
df2 = pd.read_csv('datasets/experiment/{}/fluos-lower-2.csv'.format(folder2))
od1 = pd.read_csv('datasets/experiment/{}/ods.csv'.format(folder1))
od2 = pd.read_csv('datasets/experiment/{}/ods.csv'.format(folder2))

# %%
columns = ['e16', 'e20', 'e32', 'e34', 'e41', 'e42']

# %%
df1[['positive-control-amp_0', 'positive-control-amp_1']].plot()
# Out:
# <AxesSubplot:>

# %%
mask1 = df1.columns[pd.Series(df1.columns).str.startswith(columns[1a])]
mask2 = df1.columns[pd.Series(df1.columns).str.endswith('_5')]
pd.concat([df1[mask1 & mask2], df2[mask1 & mask2]], axis=1).plot()
plt.legend()
sns.despine()
# Out:
# <ipython-input-102-efd93e6ed75c>:3: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   pd.concat([df1[mask1 & mask2], df2[mask1 & mask2]], axis=1).plot()
